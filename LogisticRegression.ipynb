# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('C:\\Users\\Tareq\\Desktop\\HR_comma_sep.csv')

df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a bar chart to show the impact of salaries on retention
plt.figure(figsize=(10, 10))
sns.countplot(x="salary", hue="left", data=df ,palette="Set2")
plt.title("Impact of Employee Salaries on Retention")
plt.xlabel("Salary Level")
plt.ylabel("Count")
plt.legend(title="Left", labels=["No", "Yes"])
plt.show()

# %%
plt.figure(figsize=(10, 10))
sns.countplot(x="Department", hue="left", data=df ,palette="Set2")
plt.title("orelation between department and employee retention")
plt.xlabel("Department")
plt.ylabel("Count")
plt.legend(title="Left", labels=["No", "Yes"])
plt.show()

# %%
plt.figure(figsize=(10, 10))
sns.countplot(x="satisfaction_level", hue="left", data=df ,palette="Set2")
plt.title("orelation between satisfaction and employee retention")
plt.xlabel("Satisfaction")
plt.ylabel("Count")
plt.legend(title="Left", labels=["No", "Yes"])
plt.show()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df[['satisfaction_level']],df.left,train_size=0.8)
X_test
# Out:
#        satisfaction_level
# 12976                0.49
# 13929                0.63
# 6754                 0.89
# 12623                0.36
# 7826                 0.67
# ...                   ...
# 13582                0.94
# 2442                 0.92
# 3379                 0.82
# 5316                 0.65
# 1659                 0.77
#
# [3000 rows x 1 columns]

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_predicted=model.predict(X_test)
y_predicted
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
model.predict_proba(X_test)
# Out:
# array([[0.70947034, 0.29052966],
#        [0.80383555, 0.19616445],
#        [0.91464767, 0.08535233],
#        ...,
#        [0.89215424, 0.10784576],
#        [0.81523449, 0.18476551],
#        [0.87303562, 0.12696438]])

# %%
model.score(X_test,y_test)
# Out:
# 0.7866666666666666
